# %%
#import required libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#load dataset
df=pd.read_csv('/content/adult_with_headers.csv')
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#print first 5rows
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
#print last 5 rows
df.tail()
# Out:
#        age      workclass  fnlwgt    education  education_num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
#shape
df.shape
# Out:
# (32561, 15)

# %%
#info abt dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#columns
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
#basic statistical info
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#checking null/missing values
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Scaling techniques
scaler_standard = StandardScaler()
scaler_minmax = MinMaxScaler()

# %%
df['hours_per_week_scaled_standard'] = scaler_standard.fit_transform(df[['hours_per_week']])
df['hours_per_week_scaled_minmax'] = scaler_minmax.fit_transform(df[['hours_per_week']])

# %%
#Encoding Techniques
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# One-Hot Encoding
onehot_cols = ['workclass', 'marital_status', 'occupation', 'relationship', 'race']
for col in onehot_cols:
    if len(df[col].unique()) < 5:
        onehot_encoder = OneHotEncoder(drop='first')
        encoded_cols = pd.DataFrame(onehot_encoder.fit_transform(df[[col]]).toarray(),
                                    columns=[col + '_' + str(i) for i in range(1, len(df[col].unique()))])
        df = pd.concat([data, encoded_cols], axis=1)

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#Feature Engineering
df['capital-gain-minus-loss'] = df['capital_gain'] - df['capital_loss']
df['age_squared'] = df['age'] ** 2

# %%
df['capital-gain-minus-loss']
# Out:
# 0         2174
# 1            0
# 2            0
# 3            0
# 4            0
#          ...
# 32556        0
# 32557        0
# 32558        0
# 32559        0
# 32560    15024
# Name: capital-gain-minus-loss, Length: 32561, dtype: int64

# %%
df['age_squared']
# Out:
# 0        1521
# 1        2500
# 2        1444
# 3        2809
# 4         784
#          ...
# 32556     729
# 32557    1600
# 32558    3364
# 32559     484
# 32560    2704
# Name: age_squared, Length: 32561, dtype: int64

# %%
# Apply log transformation to skewed numerical feature (assuming 'capital-gain' is skewed)
import numpy as np
df['capital-gain_log'] = np.log1p(df['capital_gain'])

# %%
#Feature Selection
from sklearn.ensemble import IsolationForest
import numpy as np

# %%
# Assuming your dataset is a pandas DataFrame called `data`
iso_forest = IsolationForest(contamination=0.05, random_state=42)  # Set contamination to estimate outlier proportion

# %%
pip install ppscore

# %%
import ppscore as pps

# Generate PPS matrix
pps_matrix = pps.matrix(df)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# ...

# %%
corr_matrix = df.corr()
# Out:
# <ipython-input-23-b69b4b6a6184>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                                      age    fnlwgt  education_num  \
# age                             1.000000 -0.076646       0.036527
# fnlwgt                         -0.076646  1.000000      -0.043195
# education_num                   0.036527 -0.043195       1.000000
# capital_gain                    0.077674  0.000432       0.122630
# capital_loss                    0.057775 -0.010252       0.079923
# hours_per_week                  0.068756 -0.018768       0.148123
# hours_per_week_scaled_standard  0.068756 -0.018768       0.148123
# hours_per_week_scaled_minmax    0.068756 -0.018768       0.148123
# capital-gain-minus-loss         0.074284  0.000988       0.117891
# age_squared                     0.980872 -0.075042       0.002446
# capital-gain_log                0.124183 -0.004414       0.129135
#
#                                 capital_gain  capital_loss  hours_per_week  \
# age                                 0.077674      0.057775        0.068756
# ...

# %%
print("PPS Matrix:\n", pps_matrix[['x', 'y', 'ppscore']])
# Out:
# PPS Matrix:
#                      x                               y   ppscore
# 0                 age                             age  1.000000
# 1                 age                       workclass  0.011232
# 2                 age                          fnlwgt  0.000000
# 3                 age                       education  0.052315
# 4                 age                   education_num  0.000000
# ..                ...                             ...       ...
# 395  capital-gain_log  hours_per_week_scaled_standard  0.000000
# 396  capital-gain_log    hours_per_week_scaled_minmax  0.000000
# 397  capital-gain_log         capital-gain-minus-loss  0.845392
# 398  capital-gain_log                     age_squared  0.000000
# 399  capital-gain_log                capital-gain_log  1.000000
#
# [400 rows x 3 columns]
