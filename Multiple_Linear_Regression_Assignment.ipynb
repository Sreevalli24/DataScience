# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %%
#load the dataset
df=pd.read_csv("/content/ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS(EDA1)**

# %%
#to find shape
df.shape
# Out:
# (1436, 11)

# %%
#columns
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
#info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.isnull()
# Out:
#       Price  Age_08_04     KM  Fuel_Type     HP  Automatic     cc  Doors  \
# 0     False      False  False      False  False      False  False  False
# 1     False      False  False      False  False      False  False  False
# 2     False      False  False      False  False      False  False  False
# 3     False      False  False      False  False      False  False  False
# 4     False      False  False      False  False      False  False  False
# ...     ...        ...    ...        ...    ...        ...    ...    ...
# 1431  False      False  False      False  False      False  False  False
# 1432  False      False  False      False  False      False  False  False
# 1433  False      False  False      False  False      False  False  False
# 1434  False      False  False      False  False      False  False  False
# 1435  False      False  False      False  False      False  False  False
#
#       Cylinders  Gears  Weight
# 0         False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
#statistical summary
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
#one hot encoding
#convert categorical variables to dummy variables
df=pd.get_dummies(df,columns=['Fuel_Type'], drop_first=True)
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
x=df.iloc[:,1:]
x
# Out:
#       Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  Weight  \
# 0            23  46986   90          0  2000      3          4      5    1165
# 1            23  72937   90          0  2000      3          4      5    1165
# 2            24  41711   90          0  2000      3          4      5    1165
# 3            26  48000   90          0  2000      3          4      5    1165
# 4            30  38500   90          0  2000      3          4      5    1170
# ...         ...    ...  ...        ...   ...    ...        ...    ...     ...
# 1431         69  20544   86          0  1300      3          4      5    1025
# 1432         72  19000   86          0  1300      3          4      5    1015
# 1433         71  17016   86          0  1300      3          4      5    1015
# 1434         70  16916   86          0  1300      3          4      5    1015
# 1435         76      1  110          0  1600      5          4      5    1114
#
# ...

# %%
y=df.iloc[:,:-11]
y
# Out:
#       Price
# 0     13500
# 1     13750
# 2     13950
# 3     14950
# 4     13750
# ...     ...
# 1431   7500
# 1432  10845
# 1433   8500
# 1434   7250
# 1435   6950
#
# [1436 rows x 1 columns]

# %%
#correlation
correlation=df.corr()
correlation
# Out:
#                      Price  Age_08_04        KM        HP  Automatic  \
# Price             1.000000  -0.876590 -0.569960  0.314990   0.033081
# Age_08_04        -0.876590   1.000000  0.505672 -0.156622   0.031717
# KM               -0.569960   0.505672  1.000000 -0.333538  -0.081854
# HP                0.314990  -0.156622 -0.333538  1.000000   0.013144
# Automatic         0.033081   0.031717 -0.081854  0.013144   1.000000
# cc                0.126389  -0.098084  0.102683  0.035856   0.066740
# Doors             0.185326  -0.148359 -0.036197  0.092424  -0.027654
# Cylinders              NaN        NaN       NaN       NaN        NaN
# Gears             0.063104  -0.005364  0.015023  0.209477  -0.098555
# Weight            0.581198  -0.470253 -0.028598  0.089614   0.057249
# Fuel_Type_Diesel  0.054084  -0.097740  0.403060 -0.533453  -0.084490
# Fuel_Type_Petrol -0.038516   0.092611 -0.433160  0.489110   0.080249
#
# ...

# %%
#heatmap
import seaborn as sns
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
#Visualization - Boxplot
import matplotlib.pyplot as plt
sns.boxplot(x='Fuel_Type_Diesel',y='Price',data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
sns.boxplot(x='Fuel_Type_Petrol',y='Price',data=df)
plt.show()

# %%
#visualization - pairplot
sns.pairplot(df)

# %% [markdown]
# **Splitting the dataset into training and testing datasets.**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1148, 11), (288, 11), (1148, 1), (288, 1))

# %% [markdown]
# **Model Building**

# %%
models=[]

# %%
#Model1 : Linear Regression(OLS) - ordinary least square method
from sklearn.linear_model import LinearRegression
#creating an object of linear regression class
LR=LinearRegression()
#fitting the training data
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
models.append(('OLS', LR))

# %%
#Model2 : Lasso Regression
from sklearn.linear_model import Lasso
#creating an object of lasso regression class
lasso=Lasso(alpha=0.1, random_state=42)
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1, random_state=42)

# %%
models.append(('Lasso', lasso))

# %%
#Model3: Ridge Regression
from sklearn.linear_model import Ridge
#creating an object of ridge regression class
ridge=Ridge(alpha=0.1, random_state=42)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1, random_state=42)

# %%
models.append(('Ridge', ridge))

# %% [markdown]
# **Evaluating performance of the models**

# %%
from sklearn.metrics import mean_squared_error, r2_score
for name, model in models:
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"{name} - Mean Squared Error: {mse}, R^2 Score: {r2}")
# Out:
# OLS - Mean Squared Error: 2203043.8231437025, R^2 Score: 0.8348888040611082
# Lasso - Mean Squared Error: 2202270.2600246817, R^2 Score: 0.8349467801805
# Ridge - Mean Squared Error: 2202732.244167894, R^2 Score: 0.8349121559240102

# %% [markdown]
# **Applying Lasso and Ridge methods**

# %%
#Lasso Regression
lasso_model = Lasso(alpha=0.01)
lasso_model.fit(x_train, y_train)
lasso_coefficients = lasso_model.coef_
lasso_coefficients
# Out:
# array([-1.20830134e+02, -1.62323518e-02,  1.40446762e+01,  1.48676633e+02,
#        -3.03924612e-02, -6.02945961e+01,  0.00000000e+00,  5.51306478e+02,
#         2.58833283e+01, -6.81863622e+01,  1.37074474e+03])

# %%
print("Lasso Regression Coefficients:")
for feature, coef in zip(x.columns, lasso_coefficients):
    print(f"{feature}: {coef}")
# Out:
# Lasso Regression Coefficients:
# Age_08_04: -120.83013391740928
# KM: -0.01623235184847824
# HP: 14.044676230435464
# Automatic: 148.67663287203652
# cc: -0.030392461210353786
# Doors: -60.29459608745454
# Cylinders: 0.0
# Gears: 551.3064776102499
# Weight: 25.883328345222395
# Fuel_Type_Diesel: -68.18636222436528
# Fuel_Type_Petrol: 1370.744742425982

# %%
#Ridge Regression
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(x_train, y_train)
ridge_coefficients = ridge_model.coef_
ridge_coefficients
# Out:
# array([[-1.20779659e+02, -1.63240795e-02,  1.41418340e+01,
#          1.46907470e+02, -3.05094386e-02, -5.99057913e+01,
#          0.00000000e+00,  5.42272328e+02,  2.58210194e+01,
#         -1.28813072e+02,  1.29494983e+03]])

# %%
print("Ridge Regression Coefficients:")
for feature, coef in zip(x.columns, ridge_coefficients):
    print(f"{feature}: {coef}")
# Out:
# Ridge Regression Coefficients:
# Age_08_04: [-1.20779659e+02 -1.63240795e-02  1.41418340e+01  1.46907470e+02
#  -3.05094386e-02 -5.99057913e+01  0.00000000e+00  5.42272328e+02
#   2.58210194e+01 -1.28813072e+02  1.29494983e+03]

# %% [markdown]
# Interview Questions:

# %% [markdown]
# 1.What is Normalization & Standardization and how is it helpful?

# %% [markdown]
# Ans : Normalization is the process of scaling numerical data to a fixed range, typically [0,1] or [-1,1]. Standardization is the process of transforming numerical data so that it has a mean of 0 and a standard deviation of 1.
# Both techniques help in improving convergence of machine learning algorithms and avoids feature domination.

# %% [markdown]
# 2.What techniques can be used to address multicollinearity in multiple linear regression?

# %% [markdown]
# Ans : 1.Remove Highly Correlated Variables

# %% [markdown]
# 2.Perform Principal Component Analysis (PCA)

# %% [markdown]
# 3.Regularization Techniques like Ridge or Lasso Regression

# %% [markdown]
# Assumptions made during the analysis:
# There are no significant outliers in the dataset.
# The relationship between independent variables and dependent variable is linear.

# %% [markdown]
# Implications of assumptions:
# Violation of these assumptions may lead to incorrect inferences. It's important to validate these assumptions before interpreting the results.
