# %%
#importing necessary libraries, loading the dataset
import pandas as pd
df=pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#to find shape
df.shape
# Out:
# (2126, 14)

# %%
#find columns
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
#info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
#to read first five rows
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
#to read last five rows
df.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
#find unique values
df.nunique()
# Out:
# LB           153
# AC          1067
# FM           776
# UC          1364
# DL           822
# DS           114
# DP           264
# ASTV         183
# MSTV         165
# ALTV         195
# MLTV         351
# Width        261
# Tendency     111
# NSP          111
# dtype: int64

# %%
#find null values
df.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#fillna is used to replace null values
#handling null values
df.fillna(2,inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
#Checking if numeric values are stored as strings
print(df['LB'].apply(type).value_counts())
print(df['AC'].apply(type).value_counts())
print(df['DS'].apply(type).value_counts())
print(df['DP'].apply(type).value_counts())
print(df['MLTV'].apply(type).value_counts())
print(df['Width'].apply(type).value_counts())
print(df['Tendency'].apply(type).value_counts())
print(df['NSP'].apply(type).value_counts())
# Out:
# LB
# <class 'float'>    2126
# Name: count, dtype: int64
# AC
# <class 'float'>    2126
# Name: count, dtype: int64
# DS
# <class 'float'>    2126
# Name: count, dtype: int64
# DP
# <class 'float'>    2126
# Name: count, dtype: int64
# MLTV
# <class 'float'>    2126
# Name: count, dtype: int64
# Width
# <class 'float'>    2126
# Name: count, dtype: int64
# Tendency
# <class 'float'>    2126
# Name: count, dtype: int64
# NSP
# <class 'float'>    2126
# Name: count, dtype: int64

# %%
#Replacing non-numeric entries with NaN
df['LB'] = pd.to_numeric(df['LB'], errors='coerce')
df['AC'] = pd.to_numeric(df['AC'], errors='coerce')
df['DS'] = pd.to_numeric(df['DS'], errors='coerce')
df['DP'] = pd.to_numeric(df['DP'], errors='coerce')
df['MLTV'] = pd.to_numeric(df['MLTV'], errors='coerce')
df['Width'] = pd.to_numeric(df['Width'], errors='coerce')
df['Tendency'] = pd.to_numeric(df['Tendency'], errors='coerce')
df['NSP'] = pd.to_numeric(df['NSP'], errors='coerce')

# %%
#converting to float
df['LB'] = df['LB'].astype(float)
df['AC'] = df['AC'].astype(float)
df['DS'] = df['DS'].astype(float)
df['DP'] = df['DP'].astype(float)
df['MLTV'] = df['MLTV'].astype(float)
df['Width'] = df['Width'].astype(float)
df['Tendency'] = df['Tendency'].astype(float)
df['NSP'] = df['NSP'].astype(float)

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
#statistical summary
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    132.046225     0.022003     0.009894     0.004391     0.001895
# std      17.162723     0.192852     0.067540     0.003340     0.003343
# min       2.000000    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005838     0.002567     0.006536     0.003289
# max     214.000000     2.000000     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.019758     0.019929    46.995984     1.364378    10.285964
# std       0.197835     0.197820    18.813973     1.173632    21.205041
# ...

# %%
#LB (max = 214, min = 51.84):
#The range is quite large, especially since the mean (133.34) and standard deviation (11.27) most values are clustered around 133. 
#Values near the minimum (51.84) or maximum (214) could be outliers.

# %%
#Boxplot for column LB
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['LB'])
plt.show()

# %%
#Boxplot for column AC
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['AC'])
plt.show()

# %%
#Boxplot for column FM
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['FM'])
plt.show()

# %%
#Boxplot for column DS
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['DS'])
plt.show()

# %%
#Boxplot for column DP
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['DP'])
plt.show()

# %%
#Boxplot for column ASTV
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['ASTV'])
plt.show()

# %%
#Boxplot for column NSP
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['NSP'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x='NSP',y='LB',data=df)
plt.show()

# %%
#piechart
import matplotlib.pyplot as plt

# Replacing any value that is not 1, 2, or 3 with NaN
df['NSP'] = df['NSP'].apply(lambda x: x if x in [1, 2, 3] else None)

# Drop rows with NaN values in NSP column
df_new = df.dropna(subset=['NSP'])

#count of the valid NSP categories (1, 2, 3)
nsp_counts = df_new['NSP'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(7, 7))  # Set the figure size
plt.pie(nsp_counts, labels=nsp_counts.index, autopct="%2.1f%%") #autopct in python is a string or function used to generate labels inside the wedges 
#showing their numerical values
plt.title('Proportion of Categories in NSP')
plt.show()

# %%
import seaborn as sns
sns.pairplot(df)

# %%
#scatterplot
import matplotlib.pyplot as plt
x=df['NSP']
y=df['LB']
plt.title("Scatter Plot")
plt.xlabel("NSP")
plt.ylabel("LB")
plt.scatter(x,y)

# %%
#correlation coefficient
correlation=df.corr(numeric_only=True)
correlation
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.739984  0.020001 -0.115569 -0.089704 -0.757005
# AC       -0.739984  1.000000 -0.009534  0.007264  0.006756  0.976289
# FM        0.020001 -0.009534  1.000000 -0.053226  0.009718 -0.010193
# UC       -0.115569  0.007264 -0.053226  1.000000  0.190128  0.009203
# DL       -0.089704  0.006756  0.009718  0.190128  1.000000  0.009320
# DS       -0.757005  0.976289 -0.010193  0.009203  0.009320  1.000000
# DP       -0.757127  0.976273 -0.009702  0.009506  0.009891  0.999991
# ASTV      0.158413 -0.000299 -0.032691 -0.181161 -0.069361 -0.000497
# MSTV     -0.132579  0.020317  0.017055  0.189406  0.410102  0.028791
# ALTV      0.161705 -0.036638 -0.011936 -0.227304 -0.186967 -0.031967
# MLTV      0.058401 -0.080591 -0.005398 -0.049930 -0.165410 -0.080097
# Width     0.042043 -0.147534  0.097605  0.104398  0.402177 -0.156469
# Tendency -0.040147  0.245695 -0.020314 -0.062026 -0.020410  0.250933
# ...

# %%
#heatmap
import seaborn as sns
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
#Positively Correlated Variables:
# AC and DS (Correlation: 0.976289)
# AC and DP (Correlation: 0.976273)
# DS and DP (Correlation: 0.999991)
# ASTV and ALTV (Correlation: 0.357497)
# MSTV and Width (Correlation: 0.423224)
# ALTV and ASTV (Correlation: 0.357497)
# Tendency and DS (Correlation: 0.250933)
# Tendency and DP (Correlation: 0.250408)

#Above pairs exhibit positive correlation, as one variable increases, the other tends to increase as well.
#AC, DS, and DP has very high correlation (around 0.98 or 1), indicating a strong linear relationship.

# %%
#conclusion :

#The correlation analysis points to potential redundancy in the data, which could guide feature engineering and model selection.
#Outliers and the presence of unusual values in NSP suggest the need for robust preprocessing.
#Handling missing data and considering transformations will have a direct impact on the accuracy of predictive models.
